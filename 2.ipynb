# %%
from bokeh.plotting import figure, show, show, output_notebook, curdoc
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime
import os

# %%
av_api_key = "S8I1SS0F7KU6QVTO"

web.DataReader("SPY", "av-daily", start=datetime(2017, 2, 9),
                end=datetime(2017, 5, 24),
                api_key=av_api_key)
# Out:
#               open    high     low   close     volume
# 2017-02-09  229.24  230.95  229.24  230.60   65955200
# 2017-02-10  231.00  231.77  230.62  231.51   66015900
# 2017-02-13  232.08  233.07  232.05  232.77   55182100
# 2017-02-14  232.56  233.71  232.16  233.70   71109000
# 2017-02-15  233.45  235.14  233.39  234.92   86785800
# ...            ...     ...     ...     ...        ...
# 2017-05-18  235.73  237.75  235.43  236.77  107047700
# 2017-05-19  237.33  239.08  237.27  238.31  115011400
# 2017-05-22  238.90  239.71  238.82  239.52   61010600
# 2017-05-23  239.95  240.24  239.51  240.05   48341700
# 2017-05-24  240.32  240.73  239.93  240.61   46927700
#
# [73 rows x 5 columns]

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get all stock info
msft.info

# get historical market data
msft_history = msft.history(period="1y")

# %%
output_notebook()
plot = figure(x_axis_type="datetime",)

history = yf.Ticker("SPY").history(period="max")


x = history.index
y = history["Close"]


plot.line(x,y)

show(plot)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cba8d9f2-ac1b-4c95-b256-72eba5fd5d5e">Loading BokehJS ...</span>
#     </div>
# /Users/mcaplan/Documents/.venv/lib/python3.12/site-packages/bokeh/util/serialization.py:242: UserWarning: no explicit representation of timezones available for np.datetime64
#   return convert(array.astype("datetime64[us]"))
#   <div id="bbae9e02-e5e5-49de-bb9b-abb9288e4892" data-root-id="p1351" style="display: contents;"></div>

# %%
import numpy as np

np.std(history["Close"])

# history
# Out:
# np.float64(123.00554040918564)
